# %% [markdown]
# # Lab 6 Intro Notes

# %% [markdown]
# ## Make sure the stinkbug image is in the same folder as the running jupyter notebook

# %%
# %ls
# Out:
#  Volume in drive D is LEXAR
#  Volume Serial Number is 0000-0000
#
#  Directory of D:\ENGR114-2020Q1\week7
#
# 02/17/2020  10:09 AM    <DIR>          .
# 02/17/2020  10:09 AM    <DIR>          ..
# 02/17/2020  10:10 AM    <DIR>          .ipynb_checkpoints
# 02/17/2020  10:20 AM    <DIR>          __pycache__
# 02/17/2020  12:11 PM               173 call_api.py
# 02/17/2020  10:41 AM           687,537 lab5_function_worksheet.png
# 02/17/2020  12:11 PM             7,432 lab5_prelab.ipynb
# 02/19/2020  10:31 AM           515,669 lab6_flow_chart.png
# 02/19/2020  10:33 AM           234,183 lab6_intro_notes.ipynb
# 02/19/2020  10:20 AM            60,375 stinkbug.png
# 02/19/2020  10:10 AM             4,770 week7_notes_if_elif_else.ipynb
#                7 File(s)      1,510,139 bytes
#                4 Dir(s)   1,903,722,496 bytes free

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# simple image show with a color map
image = plt.imread('stinkbug.png')

fig,ax = plt.subplots(figsize=(9,9))
ax.imshow(image, cmap='terrain')
ax.set_xticks([])
ax.set_yticks([])

plt.show()
